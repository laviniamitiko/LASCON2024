# %%
import numpy as np
import os, sys, pickle
import time
import nest
import random
import quantities as pq  # noqa
from elephant.spike_train_generation import StationaryPoissonProcess
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.6.0
#  Built: Sep 28 2023 11:53:34
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
def pITD_unimodal(N, mu1=0, sigma1=10):
    return np.random.normal(mu1, sigma1, int(N))

    return np.array(X)

def pITD_bimodal(N, mu1=-160, mu2=160, sigma1=0, sigma2=0):
    X1 = np.random.normal(mu1, sigma1, int(np.floor(N/2)))
    X2 = np.random.normal(mu2, sigma2, int(np.ceil(N/2)))
    X = np.concatenate([X1, X2])
    np.random.shuffle(X)
    return np.array(X)

def ITD_to_rad(x, mITD=160):
    return (x+mITD)/((2*mITD)/np.pi)

def generate_poisson(lamb, t_stop=1150, t_start=150):
    spiketrain_array = StationaryPoissonProcess(rate=lamb*pq.Hz,t_stop=t_stop*pq.ms,t_start=t_start*pq.ms).generate_spiketrain(as_array=True)
    return spiketrain_array

# %%
gen_po = 1

# comment out to have a different randomization of random parameters each time
#np.random.seed(1234)

# total number of neurons in the network
N = 1000
# fraction of excitatory neurons
exc_inh = 0.8
# number of excitatory neurons
NE = int(exc_inh *N)
# number of inhibitory neurons
NI = N - NE

n_smpl = 0

# probability of (E --> E,I) connections
eps_exc = 0.2
# probability of (I --> E,I) connections
eps_inh = 0.5

# inhibition dominance of synaptic weights (IPSP = g x EPSP)
g = 8#10.
# EPSP strength (mV) of recurrent synapses in the local network
J_rec = .2
# (E,I) to (E,I) weights (mV)
J_exc = J_ee = J_ei = J_rec
J_inh = J_ie = J_ii = -g*J_rec

# number of neurons in the non-local network
n_ext = 1000.
# spontaneuos firing rate of the non-local network
r_ext = 1.
# overall rate of the non-local input
s_ext = n_ext * r_ext
# EPSP strength (mV) of synapses from non-local sources
J_ext = .2

# number of LGN neurons contacting one cortical neuron
n_ffw = 50.
# average firing rate of LGN neurons
r_ffw = 20.
# overall rate of the feedforward input
r_base = n_ffw * r_ffw
# EPSP strength (mV) of feedforward synapses
J_ffw = 1.

# average synaptic delay (ms)
delay = 1.
# modulation in the input
input_mod = 0.1#np.array(NE*[0.2] + NI*[.02])

# initial random preferred orientation (PO) of neurons
if gen_po:
    np.random.seed(1234)
    po_init = pITD_bimodal(N)
    file = open('po_init', 'wb'); pickle.dump(po_init, file); file.close()
    #np.random.uniform(-160., 160, N)
#po_init[0:n_smpl] = np.arange(0, 180, 180/12.)*np.pi/180
#po_init[NE:NE+n_smpl] = np.arange(0, 180, 180/12.)*np.pi/180

else:
    f = open('po_init', 'rb'); po_init = pickle.load(f); f.close()

# number of stimulus orientations to show
stim_no = 11
# range of stimuli
stim_range = np.arange(-160., 160+1, 2*160/(stim_no-1))
# trial
trial = 1
# simulation time
simtime = 1*1000.
# transient time at the beginning of the simulation
t_trans = 150.

# membrane time constant (ms)
tauMem = 20.
# voltage threshold (mV)
theta = 20.

n_cores = 4
# neuron parameters (current-based with delta synapses)
neuron_params_delta = {"C_m"      : 1.0,
                "tau_m"     : tauMem,
                "t_ref"     : 2.0,
                "E_L"       : 0.0,
                "V_min"     : -np.inf,
                "V_m"       : 0.,
                "V_reset"   : 0.,
                "V_th"      : theta,
                "I_e"       : 0.}

#########################

# define the NEST path here if needed
#nest_path = '/Users/sadra/NEST/nest/ins/lib/python3.4/site-packages/'
#if os.path.exists(nest_path): sys.path.append(nest_path)

# code path
code_path = os.getcwd()

# results path
res_path = code_path+'/Results/'
if not os.path.exists(res_path): os.mkdir(res_path)

#########################
#########################

# %%
def NEST_initiate(dt=.1, n_cores=1): # Devemos excluir essa parte?
    '''
    Inicializando o NEST

    dt: resolucao das simulacoes
    n_cores: quantos cores devem ser utilizados para a simulacao
    '''

    #NEST restart
    nest.ResetKernel()
    rng_seed = int(np.random.uniform(0, 9876)) #int(np.random.uniform(0, 12345))
    nest.SetKernelStatus({'rng_seed': rng_seed, #Use GetStatus to see all options
                          'resolution': dt,
                          'print_time': True,
                          'overwrite_files': True,
                          'local_num_threads': n_cores})

# %%
# --- stimulating the network in response to one stimulus orientation
def stimulate_network(stim_deg, stim_id=str(0)):

    # --- Start
    ti = time.time()

    NEST_initiate(n_cores=n_cores)

    print("Network ...")

    # spiking neurons
    nest.SetDefaults("iaf_psc_delta", neuron_params_delta)
    nodes_ex = nest.Create("iaf_psc_delta", NE)
    nodes_in = nest.Create("iaf_psc_delta", NI)

    nodes_all = nodes_ex + nodes_in

    # vector of total input to all neurons
    input_rate = r_base *(1.+ input_mod* np.cos(1*(ITD_to_rad(stim_deg) - ITD_to_rad(po_init)) ))

    # -- define synapses
    #external
    nest.CopyModel("static_synapse", "ext", {"weight":J_ext, "delay":delay})
    #feedforward
    nest.CopyModel("static_synapse", "ffw", {"weight":J_ffw, "delay":delay})
    # E-to-E
    nest.CopyModel("static_synapse", "exc", {"weight":J_exc, "delay":delay})
    # I-to-I
    nest.CopyModel("static_synapse", "inh", {"weight":J_inh, "delay":delay})

    # -- SETTING DEVICES TO RECORD

    # spike detector
    sp_all = nest.Create("spike_recorder", 1)

    # stationary
    nest.SetStatus(sp_all[0],
                   {"label":"spikes-all-"+stim_id+'-tr'+str(trial),
                    'record_to': "ascii",
                    "start": 0 + t_trans, "stop": simtime })

    nest.Connect(nodes_all, sp_all[0],  syn_spec={'synapse_model': 'ext'})

    # -- Connecting the network
    print("Connecting the network ...")
    
    CE = int(eps_exc* NE)
    CI = int(eps_inh* NI)

    ffw_inp = sum(nest.Create('spike_train_injector', params={"spike_times": generate_poisson(rate), "allow_offgrid_times":True}) for rate in input_rate)
    nest.Connect(ffw_inp, nodes_all, "one_to_one")

    ext_inp = nest.Create("poisson_generator")
    nest.SetStatus(ext_inp, {"rate":s_ext})
    nest.Connect(ext_inp, nodes_all, syn_spec={'synapse_model': "ext"})


    ### recurrent connectivity
    CE = int(eps_exc* NE)
    CI = int(eps_inh* NI)

    nest.rng_seed = 12345

    nest.Connect(nodes_ex, nodes_all, {"rule": "fixed_indegree", "indegree": CE, 'allow_autapses': False, "allow_multapses": False},syn_spec={'synapse_model': "exc"})
    nest.Connect(nodes_in, nodes_all, {"rule": "fixed_indegree", "indegree": CI, 'allow_autapses': False, "allow_multapses": False},syn_spec={'synapse_model': "inh"})
    
    # --- running simulations

    print("Simulating the network ...")


    print('# -- Trial # ', str(trial))
    nest.Simulate(simtime + t_trans)

    ts = time.time()
    sim_time = ts - ti
    r_avg = nest.GetStatus(sp_all[0], 'n_events')[0]/ (N*simtime/1000.)

    print('\n########################################')
    print('End of simulation.')
    print("Simulation time   : %.2f s" % sim_time)
    print("Average rate      : %.2f Hz" %  r_avg)
    print('######################################## \n')

# %%
def run_simulation():
    '''
    Simulates the response of a network of spiking neurons wit a defined network connectivity
    in response to different stimulus orientations.
    '''

    # folder
    sim_folder = 'N'+str(N)+ 'g'+str(g)

    if sim_folder in os.listdir(res_path):
        os.chdir(res_path+sim_folder)
    else:
        os.mkdir(res_path+sim_folder)
        os.chdir(res_path+sim_folder)

    # stimulation
    for stim in enumerate(stim_range):
        print('# ---')
        print('# -- orientation: ', \
        str(stim[0]+1),'/',str(stim_no)+' ('+str(stim[1])+' ms)')
        print('# ---')

        stim_id = 'st'+str(stim[0])
        stimulate_network(stim_deg=stim[1], stim_id = stim_id)

    os.chdir(code_path)

# %%
trial_no = 10

# %%
# --- running network simulations for different degrees
trial = 0
con_gen = 0

run_simulation()
con_gen = 0

while trial < trial_no:
    trial = trial + 1
    run_simulation()
# Out:
# # ---
# # -- orientation:  1 / 11 (-160.0 ms)
# # ---
#
# Jan 23 09:38:09 SimulationManager::set_status [Info]:
# Network ...
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Connecting the network ...
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 7.49 s
# Average rate      : 3.99 Hz
# ########################################
#
# # ---
# # -- orientation:  2 / 11 (-128.0 ms)
# # ---
#
# Jan 23 09:38:16 NodeManager::prepare_nodes [Info]:
# Network ...
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:38:16 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14Connecting the network ....4065
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.6339
#
# Jan 23 09:38:16 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:38:16 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 23 09:38:23 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 7.18 s
# Average rate      : 4.05 Hz
# ########################################
#
# # ---
# # -- orientation:  3 / 11 (-96.0 ms)
# # ---
# Network ...
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:38:23 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   8% ]Connecting the network ...-time factor: 0.2816
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.4163
#
# Jan 23 09:38:24 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:38:24 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 23 09:38:30 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:38:30 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   3% ] Model time: 32.0 ms, Real-time factor: 0.2902
# ########################################
# End of simulation.
# Simulation time   : 6.89 s
# Average rate      : 4.11 Hz
# ########################################
#
# # ---
# # -- orientation:  4 / 11 (-64.0 ms)
# # ---
# Network ...
# [   5% ] Model time: 50.0 ms, Real-time facConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.4138
#
# Jan 23 09:38:30 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:38:30 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 23 09:38:37 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:38:37 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  11% ] Model time: 123.0 ms, Real-time factor: 0.2827
# ########################################
# End of simulation.
# Simulation time   : 7.09 s
# Average rate      : 4.10 Hz
# ########################################
#
# # ---
# # -- orientation:  5 / 11 (-32.0 ms)
# # ---
# Network ...
# [  16% ] Model time: 1Connecting the network ... 0.3053
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.4504
#
# Jan 23 09:38:38 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:38:38 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 23 09:38:44 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:38:44 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 0.4196
# ########################################
# End of simulation.
# Simulation time   : 7.38 s
# Average rate      : 4.00 Hz
# ########################################
#
# # ---
# # -- orientation:  6 / 11 (0.0 ms)
# # ---
# [  27% ] Model time: 3Network ...al-time factor: 0.4814
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.4682
#
# Jan 23 09:38:45 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:38:45 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Connecting the network ...
# Simulating the network ...
# # -- Trial #  0
#
# Jan 23 09:38:51 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 7.17 s
# Average rate      : 3.87 Hz
# ########################################
#
# # ---
# # -- orientation:  7 / 11 (32.0 ms)
# # ---
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:38:51 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.5471
#
# Jan 23 09:38:52 SimulationManager::run [Info]:
#     Simulation finished.
# Network ...
#
# Jan 23 09:38:52 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Connecting the network ...
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 6.97 s
# Average rate      : 3.95 Hz
# ########################################
#
# # ---
# # -- orientation:  8 / 11 (64.0 ms)
# # ---
#
# Jan 23 09:38:58 NodeManager::prepare_nodes [Info]:
# Network ...
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:38:58 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14Connecting the network ....3828
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.4569
#
# Jan 23 09:38:59 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:38:59 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 23 09:39:05 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 6.67 s
# Average rate      : 4.07 Hz
# ########################################
#
# # ---
# # -- orientation:  9 / 11 (96.0 ms)
# # ---
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:39:05 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14Network ...-time factor: 0.4718
# [   5% ] Model time: 50.0 ms, Real-time facConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.4925
#
# Jan 23 09:39:06 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:39:06 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 23 09:39:12 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:39:12 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 0.3866
# ########################################
# End of simulation.
# Simulation time   : 6.85 s
# Average rate      : 4.21 Hz
# ########################################
#
# # ---
# # -- orientation:  10 / 11 (128.0 ms)
# # ---
# Network ...
# [   6% ] Model time: 68.0 ms, Real-time factor: 0.326Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.4677
#
# Jan 23 09:39:13 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:39:13 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 23 09:39:19 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:39:19 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 0.3809
# ########################################
# End of simulation.
# Simulation time   : 7.10 s
# Average rate      : 3.93 Hz
# ########################################
#
# # ---
# # -- orientation:  11 / 11 (160.0 ms)
# # ---
# Network ...
# [   3% ] Model timeConnecting the network ...r: 0.3790
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.4412
#
# Jan 23 09:39:20 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:39:20 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 6.80 s
# Average rate      : 4.08 Hz
# ########################################
#
#
# Jan 23 09:39:26 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:39:26 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   3% ] Model time: 32.0 ms, Rea# ---e factor: 0.4196
# # -- orientation:  1 / 11 (-160.0 ms)
# # ---
# Network ...
# [   8% ]Connecting the network ...-time factor: 0.3970
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.5435
#
# Jan 23 09:39:26 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:39:26 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 23 09:39:32 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 6.60 s
# Average rate      : 3.95 Hz
# ########################################
#
# # ---
# # -- orientation:  2 / 11 (-128.0 ms)
# # ---
# Network ...
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:39:32 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   3% ] Model time: 32.0 ms, ReaConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.4903ime factor: 0.4964
#
# Jan 23 09:39:33 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:39:33 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 23 09:39:40 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:39:40 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   3% ] Model time: 32.0 ms, Real-time factor: 0.3065
# ########################################
# End of simulation.
# Simulation time   : 6.98 s
# Average rate      : 3.85 Hz
# ########################################
#
# # ---
# # -- orientation:  3 / 11 (-96.0 ms)
# # ---
# Network ...
# [   5% ] Model time: 50.0 ms, Real-time facConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.4468
#
# Jan 23 09:39:40 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:39:40 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 23 09:39:46 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:39:46 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 0.4804
# ########################################
# End of simulation.
# Simulation time   : 6.97 s
# Average rate      : 4.07 Hz
# ########################################
#
# # ---
# # -- orientation:  4 / 11 (-64.0 ms)
# # ---
# [   3% ] Model time: 32.0 ms, ReaNetwork ...or: 0.4753
# [   8% ]Connecting the network ...-time factor: 0.4323
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.5864
#
# Jan 23 09:39:47 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:39:47 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 23 09:39:53 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 6.82 s
# Average rate      : 3.94 Hz
# ########################################
#
# # ---
# # -- orientation:  5 / 11 (-32.0 ms)
# # ---
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:39:53 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14Network ...-time factor: 0.3265
# [   5% ] Model time: 50.0 ms, Real-time facConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.4187
#
# Jan 23 09:39:54 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:39:54 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 6.60 s
# Average rate      : 4.03 Hz
# ########################################
#
# # ---
# # -- orientation:  6 / 11 (0.0 ms)
# # ---
#
# Jan 23 09:40:00 NodeManager::prepare_nodes [Info]:
# Network ...
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:00 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14Connecting the network ....4478
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.5005
#
# Jan 23 09:40:00 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:00 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 6.82 s
# Average rate      : 4.15 Hz
# ########################################
#
# # ---
# # -- orientation:  7 / 11 (32.0 ms)
# # ---
#
# Jan 23 09:40:07 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:07 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   5% ] Model time: 51.0 ms,Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.4184
#
# Jan 23 09:40:07 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:07 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 5.84 s
# Average rate      : 3.90 Hz
# ########################################
#
# # ---
# # -- orientation:  8 / 11 (64.0 ms)
# # ---
#
# Jan 23 09:40:13 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:13 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   6% ] Model time: 69.0 ms, Real-timeConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1384
#
# Jan 23 09:40:13 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:13 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 1.27 s
# Average rate      : 4.11 Hz
# ########################################
#
# # ---
# # -- orientation:  9 / 11 (96.0 ms)
# # ---
#
# Jan 23 09:40:14 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:14 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   3% ] Model timeConnecting the network ...r: 0.1011
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1402
#
# Jan 23 09:40:14 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:14 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
#
# ########################################
# End of simulation.
# Simulation time   : 1.25 s
# Average rate      : 3.88 Hz
# ########################################
#
# # ---
# # -- orientation:  10 / 11 (128.0 ms)
# # ---
# Jan 23 09:40:15 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:15 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 13.0 Network ...me factor: 0.1220
# [   3% ] Model time: 31.0 ms, Real-tConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1460
#
# Jan 23 09:40:16 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:16 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 1.32 s
# Average rate      : 3.87 Hz
# ########################################
#
# # ---
# # -- orientation:  11 / 11 (160.0 ms)
# # ---
#
# Jan 23 09:40:17 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
# Connecting the network ...
#
# Jan 23 09:40:17 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1418
#
# Jan 23 09:40:17 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:17 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 1.34 s
# Average rate      : 4.05 Hz
# ########################################
#
#
# Jan 23 09:40:18 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:18 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   6% ] Model time: 69.0 ms, Real-time# ---or: 0.1267
# # -- orientation:  1 / 11 (-160.0 ms)
# # ---
# [   8% ] Model time: 87.0 ms, Real-time factor: 0Network ...
# [  10% ] Model time: 105.0 ms, Real-time factor: 0.125Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1801
#
# Jan 23 09:40:18 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:18 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  2
#
# Jan 23 09:40:20 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 1.48 s
# Average rate      : 4.15 Hz
# ########################################
#
# # ---
# # -- orientation:  2 / 11 (-128.0 ms)
# # ---
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:20 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14Network ...-time factor: 0.1368
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.2006
#
# Jan 23 09:40:20 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:20 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  2
#
# ########################################
# End of simulation.
# Simulation time   : 1.57 s
# Average rate      : 3.94 Hz
# ########################################
#
# # ---
# # -- orientation:  3 / 11 (-96.0 ms)
# # ---
#
# Jan 23 09:40:21 NodeManager::prepare_nodes [Info]:
# Network ...
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:21 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14Connecting the network ....1492
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.2012
#
# Jan 23 09:40:21 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:21 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  2
#
# ########################################
# End of simulation.
# Simulation time   : 1.35 s
# Average rate      : 4.02 Hz
# ########################################
#
# # ---
# # -- orientation:  4 / 11 (-64.0 ms)
# # ---
#
# Network ...
# Jan 23 09:40:22 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:22 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 13.0 Connecting the network ...85
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1567
#
# Jan 23 09:40:23 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:23 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  2
#
# Jan 23 09:40:24 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 1.34 s
# Average rate      : 3.96 Hz
# ########################################
#
# # ---
# # -- orientation:  5 / 11 (-32.0 ms)
# # ---
# Network ...
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:24 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   5% ] Model time: 50.0 ms, Real-time facConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1356
#
# Jan 23 09:40:24 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:24 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  2
#
# ########################################
# End of simulation.
# Simulation time   : 1.33 s
# Average rate      : 3.89 Hz
# ########################################
#
# # ---
# # -- orientation:  6 / 11 (0.0 ms)
# # ---
#
# Jan 23 09:40:25 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:25 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Connecting the network ...time factor: 0.1090
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1393
#
# Jan 23 09:40:25 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:25 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  2
#
# ########################################
# End of simulation.
# Simulation time   : 1.37 s
# Average rate      : 3.86 Hz
# ########################################
#
# # ---
# # -- orientation:  7 / 11 (32.0 ms)
# # ---
#
# Jan 23 09:40:26 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:27 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   5% ] Model time: 51.0 ms,Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1639
#
# Jan 23 09:40:27 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:27 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  2
#
# ########################################
# End of simulation.
# Simulation time   : 1.40 s
# Average rate      : 4.13 Hz
# ########################################
#
# # ---
# # -- orientation:  8 / 11 (64.0 ms)
# # ---
#
# Jan 23 09:40:28 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
# Connecting the network ...
#
# Jan 23 09:40:28 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1546
#
# Jan 23 09:40:28 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:28 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  2
#
# ########################################
# End of simulation.
# Simulation time   : 1.32 s
# Average rate      : 3.99 Hz
# ########################################
#
# # ---
# # -- orientation:  9 / 11 (96.0 ms)
# # ---
#
# Jan 23 09:40:29 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:29 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   5% ] Model time: 51.0 ms,Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1449
#
# Jan 23 09:40:29 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:29 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  2
#
# ########################################
# End of simulation.
# Simulation time   : 1.45 s
# Average rate      : 4.18 Hz
# ########################################
#
# # ---
# # -- orientation:  10 / 11 (128.0 ms)
# # ---
#
# Jan 23 09:40:31 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:31 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  38% ] Model time: 4Connecting the network ... 0.1731
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1788
#
# Jan 23 09:40:31 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:31 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  2
#
# ########################################
# End of simulation.
# Simulation time   : 1.66 s
# Average rate      : 4.01 Hz
# ########################################
#
# # ---
# # -- orientation:  11 / 11 (160.0 ms)
# # ---
#
# Jan 23 09:40:32 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:32 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  34% ] Model time: 391.0 ms, Real-tiNetwork ...0.1743
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1964
#
# Jan 23 09:40:33 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:33 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Connecting the network ...
# Simulating the network ...
# # -- Trial #  2
#
# ########################################
# End of simulation.
# Simulation time   : 1.53 s
# Average rate      : 4.04 Hz
# ########################################
#
#
# Jan 23 09:40:34 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# # ---
# # -- orientation:  1 / 11 (-160.0 ms)
# # ---
# Network ...
#
# Jan 23 09:40:34 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Connecting the network ...time factor: 0.1382
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1806
#
# Jan 23 09:40:34 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:34 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  3
#
# ########################################
# End of simulation.
# Simulation time   : 1.47 s
# Average rate      : 3.91 Hz
# ########################################
#
# # ---
# # -- orientation:  2 / 11 (-128.0 ms)
# # ---
#
# Jan 23 09:40:35 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:35 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Connecting the network ...time factor: 0.1036
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1805
#
# Jan 23 09:40:36 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:36 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  3
#
# ########################################
# End of simulation.
# Simulation time   : 1.40 s
# Average rate      : 3.92 Hz
# ########################################
#
# # ---
# # -- orientation:  3 / 11 (-96.0 ms)
# # ---
#
# Jan 23 09:40:37 NodeManager::prepare_nodes [Info]:
# Network ...
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:37 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14Connecting the network ....1164
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1529
#
# Jan 23 09:40:37 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:37 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  3
#
# Jan 23 09:40:38 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:38 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 0.1056
# ########################################
# End of simulation.
# Simulation time   : 1.34 s
# Average rate      : 4.32 Hz
# ########################################
#
# # ---
# # -- orientation:  4 / 11 (-64.0 ms)
# # ---
# [   5% ] Model time: 51.0 ms,Network ...factor: 0.0883
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1573
#
# Jan 23 09:40:38 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:38 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Connecting the network ...
# Simulating the network ...
# # -- Trial #  3
#
# Jan 23 09:40:39 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 1.25 s
# Average rate      : 3.92 Hz
# ########################################
#
# # ---
# # -- orientation:  5 / 11 (-32.0 ms)
# # ---
# Network ...
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14Connecting the network ....1268
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1378
#
# Jan 23 09:40:40 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:40 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  3
#
# ########################################
# End of simulation.
# Simulation time   : 1.39 s
# Average rate      : 3.89 Hz
# ########################################
#
# # ---
# # -- orientation:  6 / 11 (0.0 ms)
# # ---
#
# Jan 23 09:40:41 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:41 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Connecting the network ...time factor: 0.1088
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1470
#
# Jan 23 09:40:41 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:41 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  3
#
# ########################################
# End of simulation.
# Simulation time   : 1.34 s
# Average rate      : 3.77 Hz
# ########################################
#
# # ---
# # -- orientation:  7 / 11 (32.0 ms)
# # ---
#
# Jan 23 09:40:42 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:42 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Connecting the network ...time factor: 0.1194
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1375
#
# Jan 23 09:40:42 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:42 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  3
#
# Jan 23 09:40:43 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:43 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 0.1266
# ########################################
# End of simulation.
# Simulation time   : 1.27 s
# Average rate      : 4.03 Hz
# ########################################
#
# # ---
# # -- orientation:  8 / 11 (64.0 ms)
# # ---
# Network ...
# [   8% ] Model time: 87.0 ms, Real-time factor: 0Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1356
#
# Jan 23 09:40:44 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:44 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  3
#
# Jan 23 09:40:45 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 1.26 s
# Average rate      : 4.08 Hz
# ########################################
#
# # ---
# # -- orientation:  9 / 11 (96.0 ms)
# # ---
# Network ...
#
# Jan 23 09:40:45 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Connecting the network ...time factor: 0.1125
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1357
#
# Jan 23 09:40:45 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:45 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  3
#
# ########################################
# End of simulation.
# Simulation time   : 1.25 s
# Average rate      : 4.00 Hz
# ########################################
#
# # ---
# # -- orientation:  10 / 11 (128.0 ms)
# # ---
#
# Jan 23 09:40:46 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:46 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   5% ] Model time: 51.0 ms,Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1419
#
# Jan 23 09:40:46 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:46 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  3
#
# ########################################
# End of simulation.
# Simulation time   : 1.28 s
# Average rate      : 3.91 Hz
# ########################################
#
# # ---
# # -- orientation:  11 / 11 (160.0 ms)
# # ---
#
# Jan 23 09:40:47 NodeManager::prepare_nodes [Info]:
# Network ...
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:47 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14Connecting the network ....1098
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1377
#
# Jan 23 09:40:47 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:47 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  3
#
# ########################################
# End of simulation.
# Simulation time   : 1.32 s
# Average rate      : 4.02 Hz
# ########################################
#
#
# Jan 23 09:40:48 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:48 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   5% ] Model time: 51.0 ms,# ----time factor: 0.0974
# # -- orientation:  1 / 11 (-160.0 ms)
# # ---
# Network ...
# [   6% ] Model time: 69.0 ms, Real-timeConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1871
#
# Jan 23 09:40:49 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:49 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  4
#
# ########################################
# End of simulation.
# Simulation time   : 1.25 s
# Average rate      : 3.95 Hz
# ########################################
#
# # ---
# # -- orientation:  2 / 11 (-128.0 ms)
# # ---
#
# Jan 23 09:40:50 NodeManager::prepare_nodes [Info]:
# Network ...
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:50 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14Connecting the network ....1236
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1371
#
# Jan 23 09:40:50 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:50 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  4
#
# ########################################
# End of simulation.
# Simulation time   : 1.24 s
# Average rate      : 4.00 Hz
# ########################################
#
# # ---
# # -- orientation:  3 / 11 (-96.0 ms)
# # ---
#
# Jan 23 09:40:51 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:51 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Connecting the network ...time factor: 0.1204
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1369
#
# Jan 23 09:40:51 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:51 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  4
#
# ########################################
# End of simulation.
# Simulation time   : 1.28 s
# Average rate      : 3.92 Hz
# ########################################
#
# # ---
# # -- orientation:  4 / 11 (-64.0 ms)
# # ---
#
# Jan 23 09:40:52 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:40:52 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   8% ] Model time: 87.0 ms, Real-time factor: 0Network ...
# [  10% ] Model time: 105.0 ms, Real-time factor: 0.089Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1360
#
# Jan 23 09:40:52 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:52 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  4
#
# ########################################
# End of simulation.
# Simulation time   : 1.39 s
# Average rate      : 3.94 Hz
# ########################################
#
# # ---
# # -- orientation:  5 / 11 (-32.0 ms)
# # ---
#
# Jan 23 09:40:54 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:54 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Connecting the network ...time factor: 0.1346
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1379
#
# Jan 23 09:40:54 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:54 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  4
#
# ########################################
# End of simulation.
# Simulation time   : 1.25 s
# Average rate      : 4.03 Hz
# ########################################
#
# # ---
# # -- orientation:  6 / 11 (0.0 ms)
# # ---
#
# Jan 23 09:40:55 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:55 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Connecting the network ...time factor: 0.1276
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1388
#
# Jan 23 09:40:55 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:55 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  4
#
# ########################################
# End of simulation.
# Simulation time   : 1.37 s
# Average rate      : 4.10 Hz
# ########################################
#
# # ---
# # -- orientation:  7 / 11 (32.0 ms)
# # ---
#
# Jan 23 09:40:56 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:56 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   6% ] Model time: 69.0 ms, Real-timeConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1375
#
# Jan 23 09:40:56 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:56 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  4
#
# ########################################
# End of simulation.
# Simulation time   : 1.30 s
# Average rate      : 3.91 Hz
# ########################################
#
# # ---
# # -- orientation:  8 / 11 (64.0 ms)
# # ---
#
# Jan 23 09:40:58 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:58 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   6% ] Model time: 69.0 ms, Real-timeConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1400
#
# Jan 23 09:40:58 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:58 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  4
#
# ########################################
# End of simulation.
# Simulation time   : 1.37 s
# Average rate      : 4.09 Hz
# ########################################
#
# # ---
# # -- orientation:  9 / 11 (96.0 ms)
# # ---
#
# Jan 23 09:40:59 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:40:59 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   8% ] Model time: 87.0 ms, Real-time factor: 0Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1377
#
# Jan 23 09:40:59 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:40:59 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  4
#
# ########################################
# End of simulation.
# Simulation time   : 1.26 s
# Average rate      : 4.06 Hz
# ########################################
#
# # ---
# # -- orientation:  10 / 11 (128.0 ms)
# # ---
#
# Jan 23 09:41:00 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
# Connecting the network ...
#
# Jan 23 09:41:00 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1412
#
# Jan 23 09:41:00 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:41:00 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  4
#
# ########################################
# End of simulation.
# Simulation time   : 1.34 s
# Average rate      : 3.95 Hz
# ########################################
#
# # ---
# # -- orientation:  11 / 11 (160.0 ms)
# # ---
#
# Jan 23 09:41:01 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:41:01 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Connecting the network ...time factor: 0.1402
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1905
#
# Jan 23 09:41:02 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:41:02 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  4
#
# ########################################
# End of simulation.
# Simulation time   : 1.41 s
# Average rate      : 3.95 Hz
# ########################################
#
#
# Jan 23 09:41:03 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
#
# Jan 23 09:41:03 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   5% ] Model time: 50.0 ms, Real-time fac# ---0.1275
# # -- orientation:  1 / 11 (-160.0 ms)
# # ---
# Network ...
# [  11Connecting the network ...Real-time factor: 0.1216
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1419
#
# Jan 23 09:41:03 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:41:03 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  5
#
# ########################################
# End of simulation.
# Simulation time   : 1.28 s
# Average rate      : 4.03 Hz
# ########################################
#
# # ---
# # -- orientation:  2 / 11 (-128.0 ms)
# # ---
#
# Jan 23 09:41:04 NodeManager::prepare_nodes [Info]:
#     Preparing 2008 nodes for simulation.
# Network ...
#
# Jan 23 09:41:04 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   5% ] Model time: 51.0 ms,Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 0.1416
#
# Jan 23 09:41:04 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 23 09:41:04 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  5
#
# ########################################
# End of simulation.
# Simulation time   : 1.24 s
# Average rate      : 4.17 Hz
# ########################################
#
# # ---
# # -- orientation:  3 / 11 (-96.0 ms)
# # ---
#
# Jan 23 09:41:05 NodeManager::prepare_nodes [Info]:
# Network ...
# Connecting the network ...
# ...
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:09 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [  38% ] Model time: 426.0 ms, Real-time factor: 1.4276
# ########################################
# End of simulation.
# Simulation time   : 2.82 s
# Average rate      : 2.50 Hz
# ########################################
#
# # ---
# # -- orientation:  36 / 51 (64.0000000000002 ms)
# # ---
# Network ...
# [  52%Connecting the network ...eal-time factor: 1.4160
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.4912e factor: 1.4051
#
# Dec 17 20:10:10 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:10 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:12 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 2.81 s
# Average rate      : 2.51 Hz
# ########################################
#
# # ---
# # -- orientation:  37 / 51 (70.4000000000002 ms)
# # ---
# Network ...
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:12 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [  30% ] Model time: Connecting the network ...: 1.4039
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.3789me factor: 1.3694me: 1068.0 ms, Real-time factor: 1.3752
#
# Dec 17 20:10:13 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:13 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:14 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 2.71 s
# Average rate      : 2.49 Hz
# ########################################
#
# # ---
# # -- orientation:  38 / 51 (76.80000000000021 ms)
# # ---
#
# Dec 17 20:10:14 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   2% ] Network ... 14.0 ms, Real-time factor: 1.3904
# [   5% ] Model time: 51.0 ms,Connecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.4260: 1.3631
#
# Dec 17 20:10:16 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:16 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:17 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:17 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 1.3043
# ########################################
# End of simulation.
# Simulation time   : 2.73 s
# Average rate      : 2.53 Hz
# ########################################
#
# # ---
# # -- orientation:  39 / 51 (83.20000000000022 ms)
# # ---
# Network ...
# [   6% ] Model time: 69.0 ms, Real-timeConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.43622.0 ms, Real-time factor: 1.4246 Real-time factor: 1.4160
#
# Dec 17 20:10:19 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:19 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.93 s
# Average rate      : 2.51 Hz
# ########################################
#
# # ---
# # -- orientation:  40 / 51 (89.60000000000022 ms)
# # ---
#
# Dec 17 20:10:20 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:20 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   5% ] Model time: 51.0 ms,Network ...factor: 1.6366
# [  33% ] Model time: 373.0 ms, Real-time factoConnecting the network ...
# Connecting the network ...
# [  89% ] Model time: 1
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.5732
#
# Dec 17 20:10:22 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:22 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.63 s
# Average rate      : 2.52 Hz
# ########################################
#
# # ---
# # -- orientation:  41 / 51 (96.00000000000023 ms)
# # ---
#
# Dec 17 20:10:23 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:23 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   3% ] Model timeNetwork ...Real-time factor: 1.2397
# [  33% ] Model time: 373.0 ms, Real-time factoConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.3874] Model time: 588.0 ms, Real-time factor: 1.27509
#
# Dec 17 20:10:24 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:24 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.76 s
# Average rate      : 2.50 Hz
# ########################################
#
# # ---
# # -- orientation:  42 / 51 (102.4000000000002 ms)
# # ---
#
# Dec 17 20:10:25 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
# Network ...
#
# Dec 17 20:10:25 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   3% ] Model timeConnecting the network ...r: 1.7098
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.4520] Model time: 213.0 ms, Real-time factor: 1.516177.0 ms, Real-time factor: 1.4785Real-time factor: 1.4468
#
# Dec 17 20:10:27 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:27 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.72 s
# Average rate      : 2.51 Hz
# ########################################
#
# # ---
# # -- orientation:  43 / 51 (108.80000000000024 ms)
# # ---
#
# Dec 17 20:10:28 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
# Network ...
#
# Dec 17 20:10:28 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [  34% ] Model time: 391.0 ms, Real-tiConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.35692.0 ms, Real-time factor: 1.4115
#
# Dec 17 20:10:30 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:30 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.44 s
# Average rate      : 2.52 Hz
# ########################################
#
# # ---
# # -- orientation:  44 / 51 (115.20000000000027 ms)
# # ---
#
# Dec 17 20:10:31 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
# Network ...
#
# Dec 17 20:10:31 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   3% ] Model timeConnecting the network ...r: 1.2768
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.2440] Model time: 338.0 ms, Real-time factor: 1.2519 ] Model time: 713.0 ms, Real-time factor: 1.2487time factor: 1.2412
#
# Dec 17 20:10:32 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:32 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:33 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:33 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 1.2581
# ########################################
# End of simulation.
# Simulation time   : 2.72 s
# Average rate      : 2.55 Hz
# ########################################
#
# # ---
# # -- orientation:  45 / 51 (121.60000000000025 ms)
# # ---
# Network ...
# [  14% ] Model time: 159.0 ms,Connecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.4924time: 570.0 ms, Real-time factor: 1.3867 ms, Real-time factor: 1.4556
#
# Dec 17 20:10:35 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:35 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:36 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:36 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 1.4254
# ########################################
# End of simulation.
# Simulation time   : 2.88 s
# Average rate      : 2.55 Hz
# ########################################
#
# # ---
# # -- orientation:  46 / 51 (128.00000000000023 ms)
# # ---
# [   3% ] Model timeNetwork ...Real-time factor: 1.3712
# [  24% ] Model time: 266.0 ms, Real-tiConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.3486time: 445.0 ms, Real-time factor: 1.3305r: 1.3439
#
# Dec 17 20:10:38 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:38 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.74 s
# Average rate      : 2.57 Hz
# ########################################
#
# # ---
# # -- orientation:  47 / 51 (134.40000000000026 ms)
# # ---
#
# Dec 17 20:10:39 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   5% ] Model time: 51.0 ms,Network ...factor: 1.4434
# [  47% ] Model time: 534.0 ms,Connecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.4190] Model time: 838.0 ms, Real-time factor: 1.4482
#
# Dec 17 20:10:40 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:40 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 3.03 s
# Average rate      : 2.55 Hz
# ########################################
#
# # ---
# # -- orientation:  48 / 51 (140.8000000000003 ms)
# # ---
#
# Dec 17 20:10:42 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:42 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [  17% ] ModelNetwork ...0 ms, Real-time factor: 1.6996
# [  22% ] Model time: 248.0 ms, Real-time factoConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.6780: 1.6056me factor: 1.6782
#
# Dec 17 20:10:43 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:43 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:45 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:45 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 1.7398
# ########################################
# End of simulation.
# Simulation time   : 2.99 s
# Average rate      : 2.55 Hz
# ########################################
#
# # ---
# # -- orientation:  49 / 51 (147.20000000000027 ms)
# # ---
# [   3% ] Model timeNetwork ...Real-time factor: 1.9302
# [  27% ] Model time: 3Connecting the network ... 1.7999
# Connecting the network ...
# [ 100% ] Mo
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.5592
#
# Dec 17 20:10:46 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:46 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:47 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 2.65 s
# Average rate      : 2.53 Hz
# ########################################
#
# # ---
# # -- orientation:  50 / 51 (153.60000000000025 ms)
# # ---
# Network ...
#
# Dec 17 20:10:47 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   6% ] Model time: 69.0 ms, Real-timeConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.3943: 1.4075 ] Model time: 713.0 ms, Real-time factor: 1.4128 ] Model time: 1104.0 ms, Real-time factor: 1.3943
#
# Dec 17 20:10:49 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:49 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.87 s
# Average rate      : 2.54 Hz
# ########################################
#
# # ---
# # -- orientation:  51 / 51 (160.00000000000028 ms)
# # ---
#
# Dec 17 20:10:50 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
# Network ...
#
# Dec 17 20:10:50 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [  22% ] Model time: 248.0 ms, Real-time factoConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.42987.0 ms, Real-time factor: 1.533927.0 ms, Real-time factor: 1.4555
#
# Dec 17 20:10:52 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:52 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:53 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:53 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 1.3416
# ########################################
# End of simulation.
# Simulation time   : 2.71 s
# Average rate      : 2.57 Hz
# ########################################
#
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.4255Real-time factor: 1.3727
#
# Dec 17 20:10:55 SimulationManager::run [Info]:
#     Simulation finished.
