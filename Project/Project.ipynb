# %%
import numpy as np
import os, sys, pickle
import time
import nest
import random
import quantities as pq  # noqa
from elephant.spike_train_generation import StationaryPoissonProcess
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.6.0
#  Built: Sep 28 2023 11:53:34
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
def pITD_unimodal(N, mu1=0, sigma1=10):
    return np.random.normal(mu1, sigma1, int(N))

    return np.array(X)

def pITD_bimodal(N, mu1=-160, mu2=160, sigma1=0, sigma2=0):
    X1 = np.random.normal(mu1, sigma1, int(np.floor(N/2)))
    X2 = np.random.normal(mu2, sigma2, int(np.ceil(N/2)))
    X = np.concatenate([X1, X2])
    np.random.shuffle(X)
    return np.array(X)

def ITD_to_rad(x, mITD=160):
    return (x+mITD)/((2*mITD)/np.pi)

def generate_poisson(lamb, t_stop=1150, t_start=150):
    spiketrain_array = StationaryPoissonProcess(rate=lamb*pq.Hz,t_stop=t_stop*pq.ms,t_start=t_start*pq.ms).generate_spiketrain(as_array=True)
    return spiketrain_array

# %%
gen_po = 0

# comment out to have a different randomization of random parameters each time
#np.random.seed(1234)

# total number of neurons in the network
N = 12500
# fraction of excitatory neurons
exc_inh = 0.8
# number of excitatory neurons
NE = int(exc_inh *N)
# number of inhibitory neurons
NI = N - NE

n_smpl = 0

# probability of (E --> E,I) connections
eps_exc = 0.2
# probability of (I --> E,I) connections
eps_inh = 0.5

# inhibition dominance of synaptic weights (IPSP = g x EPSP)
g = 8#10.
# EPSP strength (mV) of recurrent synapses in the local network
J_rec = 0.5#0.01#.2
# (E,I) to (E,I) weights (mV)
J_exc = J_rec
J_inh = -g*J_rec

# number of neurons in the non-local network
n_ext = 1000.
# spontaneuos firing rate of the non-local network
r_ext = 1.
# overall rate of the non-local input
s_ext = n_ext * r_ext
# EPSP strength (mV) of synapses from non-local sources
J_ext = .2

# number of LGN neurons contacting one cortical neuron
n_ffw = 50.
# average firing rate of LGN neurons
r_ffw = 20.
# overall rate of the feedforward input
r_base = n_ffw * r_ffw
# EPSP strength (mV) of feedforward synapses
J_ffw = 1.

# average synaptic delay (ms)
delay = 1.
# modulation in the input
input_mod = 0.1#np.array(NE*[0.2] + NI*[.02])

# initial random preferred orientation (PO) of neurons
if gen_po:
    np.random.seed(1234)
    po_init = pITD_bimodal(N)
    file = open('po_init', 'wb'); pickle.dump(po_init, file); file.close()

else:
    f = open('po_init', 'rb'); po_init = pickle.load(f); f.close()

# number of stimulus orientations to show
stim_no = 33
# range of stimuli
stim_range = np.arange(-160., 160+1, 2*160/(stim_no-1))
# trial
trial = 1
# simulation time
simtime = 1*1000.
# transient time at the beginning of the simulation
t_trans = 150.

# membrane time constant (ms)
tauMem = 20.
# voltage threshold (mV)
theta = 20.

n_cores = 4
# neuron parameters (current-based with delta synapses)
neuron_params_delta = {"C_m"      : 1.0,
                "tau_m"     : tauMem,
                "t_ref"     : 2.0,
                "E_L"       : 0.0,
                "V_min"     : -np.inf,
                "V_m"       : 0.,
                "V_reset"   : 0.,
                "V_th"      : theta,
                "I_e"       : 0.}

#########################

# define the NEST path here if needed
#nest_path = '/Users/sadra/NEST/nest/ins/lib/python3.4/site-packages/'
#if os.path.exists(nest_path): sys.path.append(nest_path)

# code path
code_path = os.getcwd()

# results path
res_path = code_path+'/Results/'
if not os.path.exists(res_path): os.mkdir(res_path)

#########################
#########################

# %%
def NEST_initiate(dt=.1, n_cores=1): # Devemos excluir essa parte?
    '''
    Inicializando o NEST

    dt: resolucao das simulacoes
    n_cores: quantos cores devem ser utilizados para a simulacao
    '''

    #NEST restart
    nest.ResetKernel()
    rng_seed = int(np.random.uniform(0, 9876)) #int(np.random.uniform(0, 12345))
    nest.SetKernelStatus({'rng_seed': rng_seed, #Use GetStatus to see all options
                          'resolution': dt,
                          'print_time': True,
                          'overwrite_files': True,
                          'local_num_threads': n_cores})

# %%
# --- stimulating the network in response to one stimulus orientation
def stimulate_network(stim_deg, stim_id=str(0)):

    # --- Start
    ti = time.time()

    NEST_initiate(n_cores=n_cores)

    print("Network ...")

    # spiking neurons
    nest.SetDefaults("iaf_psc_delta", neuron_params_delta)
    nodes_ex = nest.Create("iaf_psc_delta", NE)
    nodes_in = nest.Create("iaf_psc_delta", NI)

    nodes_all = nodes_ex + nodes_in

    # vector of total input to all neurons
    input_rate = r_base *(1.+ input_mod* np.cos(1*(ITD_to_rad(stim_deg) - ITD_to_rad(po_init)) ))

    # -- define synapses
    #external
    nest.CopyModel("static_synapse", "ext", {"weight":J_ext, "delay":delay})
    #feedforward
    nest.CopyModel("static_synapse", "ffw", {"weight":J_ffw, "delay":delay})
    # E-to-E
    nest.CopyModel("static_synapse", "exc", {"weight":J_exc, "delay":delay})
    # I-to-I
    nest.CopyModel("static_synapse", "inh", {"weight":J_inh, "delay":delay})

    # -- SETTING DEVICES TO RECORD

    # spike detector
    sp_all = nest.Create("spike_recorder", 1)

    # stationary
    nest.SetStatus(sp_all[0],
                   {"label":"spikes-all-"+stim_id+'-tr'+str(trial),
                    'record_to': "ascii",
                    "start": 0 + t_trans, "stop": simtime })

    nest.Connect(nodes_all, sp_all[0],  syn_spec={'synapse_model': 'ext'})

    # -- Connecting the network
    print("Connecting the network ...")
    
    CE = int(eps_exc* NE)
    CI = int(eps_inh* NI)

    ffw_inp = sum(nest.Create('spike_train_injector', params={"spike_times": generate_poisson(rate), "allow_offgrid_times":True}) for rate in input_rate)
    nest.Connect(ffw_inp, nodes_all, "one_to_one")

    ext_inp = nest.Create("poisson_generator")
    nest.SetStatus(ext_inp, {"rate":s_ext})
    nest.Connect(ext_inp, nodes_all, syn_spec={'synapse_model': "ext"})


    ### recurrent connectivity
    CE = int(eps_exc* NE)
    CI = int(eps_inh* NI)

    nest.rng_seed = 12345

    nest.Connect(nodes_ex, nodes_all, {"rule": "fixed_indegree", "indegree": CE, 'allow_autapses': False, "allow_multapses": False},syn_spec={'synapse_model': "exc"})
    nest.Connect(nodes_in, nodes_all, {"rule": "fixed_indegree", "indegree": CI, 'allow_autapses': False, "allow_multapses": False},syn_spec={'synapse_model': "inh"})
    
    # --- running simulations

    print("Simulating the network ...")


    print('# -- Trial # ', str(trial))
    nest.Simulate(simtime + t_trans)

    ts = time.time()
    sim_time = ts - ti
    r_avg = nest.GetStatus(sp_all[0], 'n_events')[0]/ (N*simtime/1000.)

    print('\n########################################')
    print('End of simulation.')
    print("Simulation time   : %.2f s" % sim_time)
    print("Average rate      : %.2f Hz" %  r_avg)
    print('######################################## \n')

# %%
def run_simulation():
    '''
    Simulates the response of a network of spiking neurons with a defined network connectivity
    in response to different stimulus orientations.
    '''

    # folder
    sim_folder = 'N'+str(N)+ 'g'+str(g) + '_Jrec='+str(J_rec)

    if sim_folder in os.listdir(res_path):
        os.chdir(res_path+sim_folder)
    else:
        os.mkdir(res_path+sim_folder)
        os.chdir(res_path+sim_folder)

    # stimulation
    for stim in enumerate(stim_range):
        print('# ---')
        print('# -- orientation: ', \
        str(stim[0]+1),'/',str(stim_no)+' ('+str(stim[1])+' ms)')
        print('# ---')

        stim_id = 'st'+str(stim[0])
        stimulate_network(stim_deg=stim[1], stim_id = stim_id)

    os.chdir(code_path)

# %%
trial_no = 20

# %%
# --- running network simulations for different degrees
trial = 0
#con_gen = 0

run_simulation()
#con_gen = 0

while trial < trial_no:
    trial = trial + 1
    run_simulation()
# Out:
# # ---
# # -- orientation:  1 / 33 (-160.0 ms)
# # ---
#
# Jan 28 06:15:28 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Network ...
# Connecting the network ...
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:15:45 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 23.64 s
# Average rate      : 0.30 Hz
# ########################################
#
# # ---
# # -- orientation:  2 / 33 (-150.0 ms)
# # ---
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:15:46 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: Network ...al-time factor: 2.6894
# [  13% ] Model time: 140.0 ms, Real-time factor: 2.Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.0387
#
# Jan 28 06:15:51 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:15:51 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 23.43 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  3 / 33 (-140.0 ms)
# # ---
#
# Jan 28 06:16:09 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
# Network ...
#
# Jan 28 06:16:10 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  41Connecting the network ...Real-time factor: 4.0452
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.3173r: 4.2384
#
# Jan 28 06:16:15 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:16:15 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 22.96 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  4 / 33 (-130.0 ms)
# # ---
#
# Jan 28 06:16:32 NodeManager::prepare_nodes [Info]:
# Network ...
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:16:33 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  50% ] Model time: 569.0 Connecting the network ...40
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.0430
#
# Jan 28 06:16:38 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:16:38 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:16:57 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 27.30 s
# Average rate      : 0.30 Hz
# ########################################
#
# # ---
# # -- orientation:  5 / 33 (-120.0 ms)
# # ---
#
# Jan 28 06:16:59 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ]Network ...: 14.0 ms, Real-time factor: 4.0810
# [  83% ] ModeConnecting the network ...e factor: 5.3360
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 5.4032
#
# Jan 28 06:17:05 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:17:05 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:17:23 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:17:24 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 2.9740
# ########################################
# End of simulation.
# Simulation time   : 23.94 s
# Average rate      : 0.30 Hz
# ########################################
#
# # ---
# # -- orientation:  6 / 33 (-110.0 ms)
# # ---
# Network ...
# [  55% ] Model time: 623.0 ms, Real-time factConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.3507
#
# Jan 28 06:17:29 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:17:29 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
#
# ########################################
# End of simulation.
# Simulation time   : 23.82 s
# Average rate      : 0.28 Hz
# ########################################
#
# # ---
# # -- orientation:  7 / 33 (-100.0 ms)
# # ---
# Network ...
# Jan 28 06:17:46 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:17:47 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  47% ] Model time: 532.0 ms, Real-time factorConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.4851eal-time factor: 4.3381
#
# Jan 28 06:17:53 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:17:53 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:18:12 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:18:13 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 13.0 ms, Real-time factor: 3.2131
# ########################################
# End of simulation.
# Simulation time   : 26.16 s
# Average rate      : 0.27 Hz
# ########################################
#
# # ---
# # -- orientation:  8 / 33 (-90.0 ms)
# # ---
# Network ...
# [  48% ] Model time: 551.0 ms, RealConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.9563
#
# Jan 28 06:18:19 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:18:19 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:18:37 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 24.01 s
# Average rate      : 0.31 Hz
# ########################################
#
# # ---
# # -- orientation:  9 / 33 (-80.0 ms)
# # ---
# Network ...
#
# Jan 28 06:18:38 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  53% ] Model time: 605.0 ms, Real-time factor: 4.13Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.3055me factor: 4.1568
#
# Jan 28 06:18:43 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:18:43 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:19:01 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 24.41 s
# Average rate      : 0.28 Hz
# ########################################
#
# # ---
# # -- orientation:  10 / 33 (-70.0 ms)
# # ---
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:19:02 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  14% ] Model time: 158.0 ms, Real-time faNetwork ...2
# [  25% ] Model time: 283.0 ms, Real-time factor: 4.1936Connecting the network ...1051
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6997
#
# Jan 28 06:19:07 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:19:07 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:19:25 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 24.15 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  11 / 33 (-60.0 ms)
# # ---
# Network ...
#
# Jan 28 06:19:26 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  55% ] Model time: 623.0 ms, Real-time factor: 4.5663Connecting the network ...03
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.9755
#
# Jan 28 06:19:31 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:19:32 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:19:51 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 25.88 s
# Average rate      : 0.28 Hz
# ########################################
#
# # ---
# # -- orientation:  12 / 33 (-50.0 ms)
# # ---
#
# Jan 28 06:19:52 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ]Network ...: 14.0 ms, Real-time factor: 3.2434
# [  48% ] Model time: Connecting the network ...: 4.3410
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.5951
#
# Jan 28 06:19:57 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:19:57 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 25.72 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  13 / 33 (-40.0 ms)
# # ---
#
# Jan 28 06:20:17 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
# Network ...
#
# Jan 28 06:20:18 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  66% ] Model time: 748.0 ms, Real-time factor: 4.5035Connecting the network ...75
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6164
#
# Jan 28 06:20:23 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:20:23 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:20:42 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 25.96 s
# Average rate      : 0.26 Hz
# ########################################
#
# # ---
# # -- orientation:  14 / 33 (-30.0 ms)
# # ---
# Network ...
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:20:44 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  59% ] Model time: 676.0 ms, RealConnecting the network ...4.5078
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6899
#
# Jan 28 06:20:49 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:20:49 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 26.10 s
# Average rate      : 0.25 Hz
# ########################################
#
# # ---
# # -- orientation:  15 / 33 (-20.0 ms)
# # ---
#
# Jan 28 06:21:08 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:21:09 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  16% ] Model time: 176.0 ms, RealNetwork ...r: 3.8213
# [  75% ] MoConnecting the network ...ime factor: 5.2147
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 5.15546% ] Model time: 873.0 ms, Real-time factor: 5.2275
#
# Jan 28 06:21:15 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:21:15 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:21:34 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:21:35 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 3.1253
# ########################################
# End of simulation.
# Simulation time   : 25.79 s
# Average rate      : 0.26 Hz
# ########################################
#
# # ---
# # -- orientation:  16 / 33 (-10.0 ms)
# # ---
# [   3% ] Model timNetwork ... Real-time factor: 3.0807
# [  44% ] Model time: 498.0 ms, Real-time factConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6058
#
# Jan 28 06:21:41 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:21:41 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:22:00 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 26.21 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  17 / 33 (0.0 ms)
# # ---
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:22:02 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: Network ...al-time factor: 3.2812
# [  31% ] Model time: 354.0 ms, Real-time factor: 4.2727Connecting the network ...: 337.0 ms, Real-time factor: 4.2463
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7588
#
# Jan 28 06:22:07 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:22:07 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 25.78 s
# Average rate      : 0.27 Hz
# ########################################
#
# # ---
# # -- orientation:  18 / 33 (10.0 ms)
# # ---
#
# Jan 28 06:22:26 NodeManager::prepare_nodes [Info]:
# Network ...
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:22:27 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  25% ] Model time: 283.0 ms, Real-time faConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7131
#
# Jan 28 06:22:33 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:22:33 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 25.61 s
# Average rate      : 0.27 Hz
# ########################################
#
# # ---
# # -- orientation:  19 / 33 (20.0 ms)
# # ---
#
# Jan 28 06:22:52 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
# Network ...
#
# Jan 28 06:22:53 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  52Connecting the network ...Real-time factor: 4.3785
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.61976
#
# Jan 28 06:22:58 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:22:59 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:23:18 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 25.75 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  20 / 33 (30.0 ms)
# # ---
# Network ...
#
# Jan 28 06:23:19 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  27% ] Model time: Connecting the network ...: 4.1060
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6923
#
# Jan 28 06:23:24 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:23:24 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:23:43 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 25.54 s
# Average rate      : 0.28 Hz
# ########################################
#
# # ---
# # -- orientation:  21 / 33 (40.0 ms)
# # ---
# Network ...
#
# Jan 28 06:23:44 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  30% ] Model time: 337.0 ms, Real-time factor: 4.1074Connecting the network ...l time: 320.0 ms, Real-time factor: 4.0688
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6254
#
# Jan 28 06:23:50 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:23:50 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:24:09 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:24:10 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 3.3119
# ########################################
# End of simulation.
# Simulation time   : 25.86 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  22 / 33 (50.0 ms)
# # ---
# Network ...
# [  52Connecting the network ...Real-time factor: 4.5841l time: 570.0 ms, Real-time factor: 4.5690
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.8403
#
# Jan 28 06:24:16 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:24:16 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 25.94 s
# Average rate      : 0.27 Hz
# ########################################
#
# # ---
# # -- orientation:  23 / 33 (60.0 ms)
# # ---
#
# Jan 28 06:24:35 NodeManager::prepare_nodes [Info]:
# Network ...
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:24:36 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  58% ] Model time: 658.0 ms, Real-time factor: 4.6969Connecting the network ...6880
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.8363
#
# Jan 28 06:24:41 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:24:42 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:25:01 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 25.88 s
# Average rate      : 0.26 Hz
# ########################################
#
# # ---
# # -- orientation:  24 / 33 (70.0 ms)
# # ---
# Network ...
#
# Jan 28 06:25:02 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  36% ] Model time: 409.0 ms, Real-time factor: 4.2921Connecting the network ...or: 4.2302
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6888
#
# Jan 28 06:25:07 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:25:08 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:25:27 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:25:28 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 3.9832
# ########################################
# End of simulation.
# Simulation time   : 26.13 s
# Average rate      : 0.27 Hz
# ########################################
#
# # ---
# # -- orientation:  25 / 33 (80.0 ms)
# # ---
# [   3% ] Model timNetwork ... Real-time factor: 3.6457
# [  34% ] Model time: 391.0 ms, Real-tConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7247
#
# Jan 28 06:25:34 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:25:34 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:25:53 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 26.57 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  26 / 33 (90.0 ms)
# # ---
# Network ...
#
# Jan 28 06:25:55 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  19Connecting the network ...Real-time factor: 3.7747l time: 195.0 ms, Real-time factor: 3.6729
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.8291
#
# Jan 28 06:26:00 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:26:00 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 26.35 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  27 / 33 (100.0 ms)
# # ---
#
# Jan 28 06:26:20 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:26:21 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   6% ] Model time: 68.0 ms, Real-time factor: 3.3Network ...
# [  61% ] Model time: 694.0 ms, Real-time factor: 4.5003Connecting the network ...ctor: 4.4863
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6453
#
# Jan 28 06:26:26 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:26:27 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 26.12 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  28 / 33 (110.0 ms)
# # ---
#
# Jan 28 06:26:46 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
# Network ...
#
# Jan 28 06:26:47 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  53% ] Model time: 605.0 ms, Real-time factor: 4.64Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7892
#
# Jan 28 06:26:53 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:26:53 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:27:12 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:27:13 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  22% ] Model time: 248.0 ms, Real-time factor: 3.7850
# ########################################
# End of simulation.
# Simulation time   : 26.44 s
# Average rate      : 0.30 Hz
# ########################################
#
# # ---
# # -- orientation:  29 / 33 (120.0 ms)
# # ---
# Network ...
# [  53% ] Model time: 605.0 ms, Real-time factor: 4.44Connecting the network ..., Real-time factor: 4.4344
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7606
#
# Jan 28 06:27:19 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:27:19 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 25.68 s
# Average rate      : 0.31 Hz
# ########################################
#
# # ---
# # -- orientation:  30 / 33 (130.0 ms)
# # ---
#
# Jan 28 06:27:38 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:27:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: Network ...al-time factor: 3.3112
# [  52% ] Model timeConnecting the network ...or: 4.4266ms, Real-time factor: 4.4152
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6433
#
# Jan 28 06:27:45 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:27:45 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 26.01 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  31 / 33 (140.0 ms)
# # ---
#
# Jan 28 06:28:04 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
# Network ...
#
# Jan 28 06:28:05 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  62% ] Model time: 712.0 ms, Real-time factor: 4.6926Connecting the network ..., Real-time factor: 4.6566
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7987
#
# Jan 28 06:28:11 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:28:11 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# ########################################
# End of simulation.
# Simulation time   : 25.66 s
# Average rate      : 0.30 Hz
# ########################################
#
# # ---
# # -- orientation:  32 / 33 (150.0 ms)
# # ---
#
# Jan 28 06:28:30 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
# Network ...
#
# Jan 28 06:28:31 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  45% ] Model time: 516.0 ms, Real-tConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7954
#
# Jan 28 06:28:36 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:28:36 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:28:56 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:28:57 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  19% ] Model time: 212.0 ms, Real-time factor: 3.8271
# ########################################
# End of simulation.
# Simulation time   : 26.32 s
# Average rate      : 0.26 Hz
# ########################################
#
# # ---
# # -- orientation:  33 / 33 (160.0 ms)
# # ---
# Network ...
# [  75% ] Model time: 855.0 ms, Real-time factor: 4.92Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.9157r: 4.9244
#
# Jan 28 06:29:03 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:29:03 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  0
#
# Jan 28 06:29:22 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:29:23 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 13.0 ms, Real-time factor: 3.3495
# ########################################
# End of simulation.
# Simulation time   : 26.22 s
# Average rate      : 0.29 Hz
# ########################################
#
# [  10% ] Mo# ---ime: 104.0 ms, Real-time factor: 3.4404
# # -- orientation:  1 / 33 (-160.0 ms)
# # ---
# Network ...
# [  59% ] Model time: 676.0 ms, RealConnecting the network ...4.5711
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7768
#
# Jan 28 06:29:29 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:29:29 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:29:48 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:29:49 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 3.2509
# ########################################
# End of simulation.
# Simulation time   : 25.81 s
# Average rate      : 0.27 Hz
# ########################################
#
# # ---
# # -- orientation:  2 / 33 (-150.0 ms)
# # ---
# Network ...
# [  55% ] Model time: 623.0 ms, Real-time factConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6270me factor: 4.4665
#
# Jan 28 06:29:55 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:29:55 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 26.69 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  3 / 33 (-140.0 ms)
# # ---
#
# Jan 28 06:30:14 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
# Network ...
#
# Jan 28 06:30:15 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  50% ] ModeConnecting the network ...e factor: 4.9190
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 5.3144
#
# Jan 28 06:30:21 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:30:22 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 27.29 s
# Average rate      : 0.30 Hz
# ########################################
#
# # ---
# # -- orientation:  4 / 33 (-130.0 ms)
# # ---
#
# Jan 28 06:30:42 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
# Network ...
#
# Jan 28 06:30:43 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  44% ] Model time: 498.0 ms, Real-time factor: 4.7771Connecting the network ...29
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 5.0545
#
# Jan 28 06:30:49 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:30:49 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:31:08 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:31:09 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 3.3004
# ########################################
# End of simulation.
# Simulation time   : 25.57 s
# Average rate      : 0.30 Hz
# ########################################
#
# # ---
# # -- orientation:  5 / 33 (-120.0 ms)
# # ---
# Network ...
# [  52% ] Model time: 587.0 ms, Real-time factor: 4.4577Connecting the network ...l time: 570.0 ms, Real-time factor: 4.4222
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6770
#
# Jan 28 06:31:14 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:31:14 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 25.63 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  6 / 33 (-110.0 ms)
# # ---
# Network ...
#
# Jan 28 06:31:33 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:31:34 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  44% ] Model time: 498.0 ms, Real-time factConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7432me factor: 4.4517
#
# Jan 28 06:31:40 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:31:40 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 26.02 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  7 / 33 (-100.0 ms)
# # ---
# Network ...
#
# Jan 28 06:31:59 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:32:01 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  Connecting the network ..., Real-time factor: 4.2275
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6814
#
# Jan 28 06:32:06 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:32:06 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:32:25 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:32:26 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 3.1981
# ########################################
# End of simulation.
# Simulation time   : 25.91 s
# Average rate      : 0.28 Hz
# ########################################
#
# # ---
# # -- orientation:  8 / 33 (-90.0 ms)
# # ---
# Network ...
# [  42% ] Model time: 480.0 ms, Real-time factor: 4.38Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7752
#
# Jan 28 06:32:32 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:32:32 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 25.63 s
# Average rate      : 0.28 Hz
# ########################################
#
# # ---
# # -- orientation:  9 / 33 (-80.0 ms)
# # ---
#
# Jan 28 06:32:51 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:32:52 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  10% ] Model time: 105.0 ms, Real-time factor: 3.52Network ...
# [  59% ] Model time: Connecting the network ...: 4.5873
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7171
#
# Jan 28 06:32:57 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:32:58 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 25.85 s
# Average rate      : 0.27 Hz
# ########################################
#
# # ---
# # -- orientation:  10 / 33 (-70.0 ms)
# # ---
#
# Jan 28 06:33:17 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
# Network ...
#
# Jan 28 06:33:18 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  52% ] Model time: 587.0 ms, Real-time factor: 4.6268Connecting the network ...l time: 570.0 ms, Real-time factor: 4.6175
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7915
#
# Jan 28 06:33:23 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:33:23 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:33:43 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 26.58 s
# Average rate      : 0.27 Hz
# ########################################
#
# # ---
# # -- orientation:  11 / 33 (-60.0 ms)
# # ---
# Network ...
#
# Jan 28 06:33:44 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  50% ] ModeConnecting the network ...e factor: 4.4136
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7485
#
# Jan 28 06:33:50 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:33:50 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:34:10 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 26.20 s
# Average rate      : 0.27 Hz
# ########################################
#
# # ---
# # -- orientation:  12 / 33 (-50.0 ms)
# # ---
# Network ...
#
# Jan 28 06:34:11 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  48% ] Model time: Connecting the network ...: 4.3942
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6825 time: 570.0 ms, Real-time factor: 4.4101
#
# Jan 28 06:34:16 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:34:16 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:34:35 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:34:36 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 3.1915
# ########################################
# End of simulation.
# Simulation time   : 25.77 s
# Average rate      : 0.28 Hz
# ########################################
#
# # ---
# # -- orientation:  13 / 33 (-40.0 ms)
# # ---
# Network ...
# [  61% ] ModeConnecting the network ...e factor: 4.7182
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.8061 ] Model time: 713.0 ms, Real-time factor: 4.7233
#
# Jan 28 06:34:42 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:34:42 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:35:01 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 26.03 s
# Average rate      : 0.27 Hz
# ########################################
#
# # ---
# # -- orientation:  14 / 33 (-30.0 ms)
# # ---
# Network ...
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:35:02 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  38% ] Model time: 426.0 ms, RealConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.8895s, Real-time factor: 4.3622
#
# Jan 28 06:35:08 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:35:08 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:35:27 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 25.62 s
# Average rate      : 0.28 Hz
# ########################################
#
# # ---
# # -- orientation:  15 / 33 (-20.0 ms)
# # ---
# Network ...
#
# Jan 28 06:35:28 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  47% ] Model time: 534.0 msConnecting the network ...ime factor: 4.5260
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7261
#
# Jan 28 06:35:33 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:35:34 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:35:53 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:35:54 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 3.2706
# ########################################
# End of simulation.
# Simulation time   : 25.79 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  16 / 33 (-10.0 ms)
# # ---
# Network ...
# [  30Connecting the network ...Real-time factor: 4.1355
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7428
#
# Jan 28 06:35:59 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:35:59 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:36:18 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:36:19 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 3.2558
# ########################################
# End of simulation.
# Simulation time   : 25.57 s
# Average rate      : 0.28 Hz
# ########################################
#
# # ---
# # -- orientation:  17 / 33 (0.0 ms)
# # ---
# [   3% ] Model timNetwork ... Real-time factor: 3.2677
# [  25% ] Model time: 284.0 msConnecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6935
#
# Jan 28 06:36:25 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:36:25 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 25.76 s
# Average rate      : 0.30 Hz
# ########################################
#
# # ---
# # -- orientation:  18 / 33 (10.0 ms)
# # ---
#
# Jan 28 06:36:44 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
# Network ...
#
# Jan 28 06:36:45 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  33% ] Model time: 373.0 ms, Real-time factor: 4.1993Connecting the network ...75
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.6657
#
# Jan 28 06:36:51 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:36:51 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:37:10 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 25.93 s
# Average rate      : 0.27 Hz
# ########################################
#
# # ---
# # -- orientation:  19 / 33 (20.0 ms)
# # ---
# Network ...
#
# Jan 28 06:37:11 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  50% ] ModeConnecting the network ...e factor: 4.5185
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7282
#
# Jan 28 06:37:17 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:37:17 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 26.04 s
# Average rate      : 0.27 Hz
# ########################################
#
# # ---
# # -- orientation:  20 / 33 (30.0 ms)
# # ---
#
# Jan 28 06:37:36 NodeManager::prepare_nodes [Info]:
# Network ...
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:37:37 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  53% ] Model time: 604.0 ms, Real-time factor: 4.5523Connecting the network ...: 587.0 ms, Real-time factor: 4.5437
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7380
#
# Jan 28 06:37:43 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:37:43 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# ########################################
# End of simulation.
# Simulation time   : 27.23 s
# Average rate      : 0.29 Hz
# ########################################
#
# # ---
# # -- orientation:  21 / 33 (40.0 ms)
# # ---
#
# Jan 28 06:38:03 NodeManager::prepare_nodes [Info]:
# Network ...
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:38:04 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [  53% ] MoConnecting the network ...ime factor: 4.4608ms, Real-time factor: 4.4404
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7006
#
# Jan 28 06:38:10 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:38:10 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:38:29 NodeManager::prepare_nodes [Info]:
#     Preparing 25008 nodes for simulation.
#
# Jan 28 06:38:30 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 25008
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 4
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 3.5880
# ########################################
# End of simulation.
# Simulation time   : 25.98 s
# Average rate      : 0.28 Hz
# ########################################
#
# # ---
# # -- orientation:  22 / 33 (50.0 ms)
# # ---
# [   3% ] Model timNetwork ... Real-time factor: 3.3778
# [  59% ] Model time: Connecting the network ...: 4.6355
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 4.7861 time: 695.0 ms, Real-time factor: 4.6470
#
# Jan 28 06:38:36 SimulationManager::run [Info]:
#     Simulation finished.
#
# Jan 28 06:38:36 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  1
#
# Jan 28 06:38:55 NodeManager::prepare_nodes [Info]:
#
# ...
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:09 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [  38% ] Model time: 426.0 ms, Real-time factor: 1.4276
# ########################################
# End of simulation.
# Simulation time   : 2.82 s
# Average rate      : 2.50 Hz
# ########################################
#
# # ---
# # -- orientation:  36 / 51 (64.0000000000002 ms)
# # ---
# Network ...
# [  52%Connecting the network ...eal-time factor: 1.4160
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.4912e factor: 1.4051
#
# Dec 17 20:10:10 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:10 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:12 NodeManager::prepare_nodes [Info]:
#
# ########################################
# End of simulation.
# Simulation time   : 2.81 s
# Average rate      : 2.51 Hz
# ########################################
#
# # ---
# # -- orientation:  37 / 51 (70.4000000000002 ms)
# # ---
# Network ...
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:12 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [  30% ] Model time: Connecting the network ...: 1.4039
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.3789me factor: 1.3694me: 1068.0 ms, Real-time factor: 1.3752
#
# Dec 17 20:10:13 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:13 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:14 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 2.71 s
# Average rate      : 2.49 Hz
# ########################################
#
# # ---
# # -- orientation:  38 / 51 (76.80000000000021 ms)
# # ---
#
# Dec 17 20:10:14 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   2% ] Network ... 14.0 ms, Real-time factor: 1.3904
# [   5% ] Model time: 51.0 ms,Connecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.4260: 1.3631
#
# Dec 17 20:10:16 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:16 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:17 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:17 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 1.3043
# ########################################
# End of simulation.
# Simulation time   : 2.73 s
# Average rate      : 2.53 Hz
# ########################################
#
# # ---
# # -- orientation:  39 / 51 (83.20000000000022 ms)
# # ---
# Network ...
# [   6% ] Model time: 69.0 ms, Real-timeConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.43622.0 ms, Real-time factor: 1.4246 Real-time factor: 1.4160
#
# Dec 17 20:10:19 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:19 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.93 s
# Average rate      : 2.51 Hz
# ########################################
#
# # ---
# # -- orientation:  40 / 51 (89.60000000000022 ms)
# # ---
#
# Dec 17 20:10:20 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:20 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   5% ] Model time: 51.0 ms,Network ...factor: 1.6366
# [  33% ] Model time: 373.0 ms, Real-time factoConnecting the network ...
# Connecting the network ...
# [  89% ] Model time: 1
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.5732
#
# Dec 17 20:10:22 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:22 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.63 s
# Average rate      : 2.52 Hz
# ########################################
#
# # ---
# # -- orientation:  41 / 51 (96.00000000000023 ms)
# # ---
#
# Dec 17 20:10:23 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:23 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   3% ] Model timeNetwork ...Real-time factor: 1.2397
# [  33% ] Model time: 373.0 ms, Real-time factoConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.3874] Model time: 588.0 ms, Real-time factor: 1.27509
#
# Dec 17 20:10:24 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:24 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.76 s
# Average rate      : 2.50 Hz
# ########################################
#
# # ---
# # -- orientation:  42 / 51 (102.4000000000002 ms)
# # ---
#
# Dec 17 20:10:25 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
# Network ...
#
# Dec 17 20:10:25 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   3% ] Model timeConnecting the network ...r: 1.7098
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.4520] Model time: 213.0 ms, Real-time factor: 1.516177.0 ms, Real-time factor: 1.4785Real-time factor: 1.4468
#
# Dec 17 20:10:27 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:27 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.72 s
# Average rate      : 2.51 Hz
# ########################################
#
# # ---
# # -- orientation:  43 / 51 (108.80000000000024 ms)
# # ---
#
# Dec 17 20:10:28 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
# Network ...
#
# Dec 17 20:10:28 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [  34% ] Model time: 391.0 ms, Real-tiConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.35692.0 ms, Real-time factor: 1.4115
#
# Dec 17 20:10:30 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:30 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.44 s
# Average rate      : 2.52 Hz
# ########################################
#
# # ---
# # -- orientation:  44 / 51 (115.20000000000027 ms)
# # ---
#
# Dec 17 20:10:31 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
# Network ...
#
# Dec 17 20:10:31 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   3% ] Model timeConnecting the network ...r: 1.2768
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.2440] Model time: 338.0 ms, Real-time factor: 1.2519 ] Model time: 713.0 ms, Real-time factor: 1.2487time factor: 1.2412
#
# Dec 17 20:10:32 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:32 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:33 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:33 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 1.2581
# ########################################
# End of simulation.
# Simulation time   : 2.72 s
# Average rate      : 2.55 Hz
# ########################################
#
# # ---
# # -- orientation:  45 / 51 (121.60000000000025 ms)
# # ---
# Network ...
# [  14% ] Model time: 159.0 ms,Connecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.4924time: 570.0 ms, Real-time factor: 1.3867 ms, Real-time factor: 1.4556
#
# Dec 17 20:10:35 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:35 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:36 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:36 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 1.4254
# ########################################
# End of simulation.
# Simulation time   : 2.88 s
# Average rate      : 2.55 Hz
# ########################################
#
# # ---
# # -- orientation:  46 / 51 (128.00000000000023 ms)
# # ---
# [   3% ] Model timeNetwork ...Real-time factor: 1.3712
# [  24% ] Model time: 266.0 ms, Real-tiConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.3486time: 445.0 ms, Real-time factor: 1.3305r: 1.3439
#
# Dec 17 20:10:38 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:38 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.74 s
# Average rate      : 2.57 Hz
# ########################################
#
# # ---
# # -- orientation:  47 / 51 (134.40000000000026 ms)
# # ---
#
# Dec 17 20:10:39 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:39 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   5% ] Model time: 51.0 ms,Network ...factor: 1.4434
# [  47% ] Model time: 534.0 ms,Connecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.4190] Model time: 838.0 ms, Real-time factor: 1.4482
#
# Dec 17 20:10:40 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:40 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 3.03 s
# Average rate      : 2.55 Hz
# ########################################
#
# # ---
# # -- orientation:  48 / 51 (140.8000000000003 ms)
# # ---
#
# Dec 17 20:10:42 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:42 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [  17% ] ModelNetwork ...0 ms, Real-time factor: 1.6996
# [  22% ] Model time: 248.0 ms, Real-time factoConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.6780: 1.6056me factor: 1.6782
#
# Dec 17 20:10:43 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:43 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:45 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:45 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 1.7398
# ########################################
# End of simulation.
# Simulation time   : 2.99 s
# Average rate      : 2.55 Hz
# ########################################
#
# # ---
# # -- orientation:  49 / 51 (147.20000000000027 ms)
# # ---
# [   3% ] Model timeNetwork ...Real-time factor: 1.9302
# [  27% ] Model time: 3Connecting the network ... 1.7999
# Connecting the network ...
# [ 100% ] Mo
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.5592
#
# Dec 17 20:10:46 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:46 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:47 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# ########################################
# End of simulation.
# Simulation time   : 2.65 s
# Average rate      : 2.53 Hz
# ########################################
#
# # ---
# # -- orientation:  50 / 51 (153.60000000000025 ms)
# # ---
# Network ...
#
# Dec 17 20:10:47 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   6% ] Model time: 69.0 ms, Real-timeConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.3943: 1.4075 ] Model time: 713.0 ms, Real-time factor: 1.4128 ] Model time: 1104.0 ms, Real-time factor: 1.3943
#
# Dec 17 20:10:49 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:49 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# ########################################
# End of simulation.
# Simulation time   : 2.87 s
# Average rate      : 2.54 Hz
# ########################################
#
# # ---
# # -- orientation:  51 / 51 (160.00000000000028 ms)
# # ---
#
# Dec 17 20:10:50 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
# Network ...
#
# Dec 17 20:10:50 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [  22% ] Model time: 248.0 ms, Real-time factoConnecting the network ...
# Connecting the network ...
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.42987.0 ms, Real-time factor: 1.533927.0 ms, Real-time factor: 1.4555
#
# Dec 17 20:10:52 SimulationManager::run [Info]:
#     Simulation finished.
#
# Dec 17 20:10:52 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.1 ms.
# Simulating the network ...
# # -- Trial #  50
#
# Dec 17 20:10:53 NodeManager::prepare_nodes [Info]:
#     Preparing 2003 nodes for simulation.
#
# Dec 17 20:10:53 SimulationManager::start_updating_ [Info]:
#     Number of local nodes: 2003
#     Simulation time (ms): 1150
#     Number of OpenMP threads: 1
#     Not using MPI
#
# [   2% ] Model time: 14.0 ms, Real-time factor: 1.3416
# ########################################
# End of simulation.
# Simulation time   : 2.71 s
# Average rate      : 2.57 Hz
# ########################################
#
# [ 100% ] Model time: 1150.0 ms, Real-time factor: 1.4255Real-time factor: 1.3727
#
# Dec 17 20:10:55 SimulationManager::run [Info]:
#     Simulation finished.
